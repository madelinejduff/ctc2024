# %%
from datetime import datetime
from backtesterMM import Backtester
from strategyMM import Strategy

start = datetime(2024, 1, 1)
end = datetime(2024, 3, 30)
s = Strategy()
b = Backtester(start, end, s)
# Out:
# Call margin required: 48831.298828125, Put margin required: 49580.0
# Transaction cost: 0.5, Slippage: 48.831298828125 for calls
# 1000000 2024-01-17
# Call margin required: 48831.298828125, Put margin required: 49810.0
# Transaction cost: 0.5, Slippage: 48.831298828125 for calls
# 1098510.7101269532 2024-01-17
# Call margin required: 48831.298828125, Put margin required: 49720.0
# Transaction cost: 0.5, Slippage: 48.831298828125 for calls
# 1197251.6502539064 2024-01-17
# Total long position size: 0, Total short position size: 6
# Call margin required: 49021.298828125, Put margin required: 49580.0
# Transaction cost: 0.5, Slippage: 49.021298828125 for calls
# 1295902.5003808595 2024-01-17
# Call margin required: 49021.298828125, Put margin required: 49810.0
# Transaction cost: 0.5, Slippage: 49.021298828125 for calls
# 1394603.4005078126 2024-01-17
# Call margin required: 49021.298828125, Put margin required: 49720.0
# Transaction cost: 0.5, Slippage: 49.021298828125 for calls
# ...

# %%
b.calculate_pnl()
# Out:
# --- Processing date: 2024-01-01 00:00:00 ---
# End of day: 2024-01-01 00:00:00, Capital: 100000000, Portfolio Value: 0
# Date: 2024-01-02 00:00:00, Capital: 100000000, Portfolio Value: 0, Total PnL: 100000000
#
# --- Processing date: 2024-01-02 00:00:00 ---
# End of day: 2024-01-02 00:00:00, Capital: 100000000, Portfolio Value: 0
# Date: 2024-01-03 00:00:00, Capital: 100000000, Portfolio Value: 0, Total PnL: 100000000
#
# --- Processing date: 2024-01-03 00:00:00 ---
# End of day: 2024-01-03 00:00:00, Capital: 100000000, Portfolio Value: 0
# Date: 2024-01-04 00:00:00, Capital: 100000000, Portfolio Value: 0, Total PnL: 100000000
#
# --- Processing date: 2024-01-04 00:00:00 ---
# End of day: 2024-01-04 00:00:00, Capital: 100000000, Portfolio Value: 0
# Date: 2024-01-05 00:00:00, Capital: 100000000, Portfolio Value: 0, Total PnL: 100000000
#
# --- Processing date: 2024-01-05 00:00:00 ---
# End of day: 2024-01-05 00:00:00, Capital: 100000000, Portfolio Value: 0
# ...

# %%
b.plot_pnl()

# %%
b.compute_overall_score()
# Out:
# Max Drawdown: 0.005136951274827981
# Overall Return: 4.66116242629692%
# Sharpe Ratio: 0.07261817331715915
# Overall Score: 65.8922156008954
