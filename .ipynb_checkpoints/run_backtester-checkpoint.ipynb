# %%
from datetime import datetime
from backtester import Backtester
from strategyMM import Strategy

start = datetime(2024, 1, 1)
end = datetime(2024, 3, 30)
s = Strategy()
b = Backtester(start, end, s)
# Out:
# Cannot trade option SPX   240119C04760000 on expiration day or later.
# Cannot trade option SPX   240119C04760000 on expiration day or later.
# Cannot trade option SPX   240119C04760000 on expiration day or later.
# Cannot trade option SPX   240119C04760000 on expiration day or later.
# Cannot trade option SPX   240119C04760000 on expiration day or later.
# Cannot trade option SPX   240119C04760000 on expiration day or later.
# Cannot trade option SPX   240119C04760000 on expiration day or later.
# Cannot trade option SPX   240119C04760000 on expiration day or later.
# Cannot trade option SPX   240119C04760000 on expiration day or later.
# Cannot trade option SPX   240119C04760000 on expiration day or later.
# Cannot trade option SPX   240119C04760000 on expiration day or later.
# Cannot trade option SPX   240119C04760000 on expiration day or later.
# Cannot trade option SPX   240119C04760000 on expiration day or later.
# Cannot trade option SPX   240119C04760000 on expiration day or later.
# Cannot trade option SPX   240119C04760000 on expiration day or later.
# Cannot trade option SPX   240119C04760000 on expiration day or later.
# Cannot trade option SPX   240119C04760000 on expiration day or later.
# Cannot trade option SPX   240119C04760000 on expiration day or later.
# Cannot trade option SPX   240119C04765000 on expiration day or later.
# Cannot trade option SPX   240119C04765000 on expiration day or later.
# Cannot trade option SPX   240119C04765000 on expiration day or later.
# Cannot trade option SPX   240119C04765000 on expiration day or later.
# Cannot trade option SPX   240119C04765000 on expiration day or later.
# Cannot trade option SPX   240119C04765000 on expiration day or later.
# Cannot trade option SPX   240119C04765000 on expiration day or later.
# Cannot trade option SPX   240119C04765000 on expiration day or later.
# Cannot trade option SPX   240119C04765000 on expiration day or later.
# Cannot trade option SPX   240119C04750000 on expiration day or later.
# Cannot trade option SPX   240119C04750000 on expiration day or later.
# Cannot trade option SPX   240119C04750000 on expiration day or later.
# Cannot trade option SPX   240119C04750000 on expiration day or later.
# Cannot trade option SPX   240119C04750000 on expiration day or later.
# Cannot trade option SPX   240119C04750000 on expiration day or later.
# Cannot trade option SPX   240119C04750000 on expiration day or later.
# Cannot trade option SPX   240119C04750000 on expiration day or later.
# Cannot trade option SPX   240119C04750000 on expiration day or later.
# Cannot trade option SPX   240119C04745000 on expiration day or later.
# Cannot trade option SPX   240119C04745000 on expiration day or later.
# Cannot trade option SPX   240119C04745000 on expiration day or later.
# Cannot trade option SPX   240119C04745000 on expiration day or later.
# Cannot trade option SPX   240119C04745000 on expiration day or later.
# Cannot trade option SPX   240119C04745000 on expiration day or later.
# Cannot trade option SPX   240119C04745000 on expiration day or later.
# Cannot trade option SPX   240119C04745000 on expiration day or later.
# Cannot trade option SPX   240119C04745000 on expiration day or later.
# Cannot trade option SPX   240119C04770000 on expiration day or later.
# Cannot trade option SPX   240119C04770000 on expiration day or later.
# Cannot trade option SPX   240315C05150000 on expiration day or later.
# Cannot trade option SPX   240315C05150000 on expiration day or later.
# Cannot trade option SPX   240315C05150000 on expiration day or later.
# Cannot trade option SPX   240315C05150000 on expiration day or later.
# Cannot trade option SPX   240315C05150000 on expiration day or later.
# Cannot trade option SPX   240315C05150000 on expiration day or later.
# Cannot trade option SPX   240315C05150000 on expiration day or later.
# Cannot trade option SPX   240315C05150000 on expiration day or later.
# Cannot trade option SPX   240315C05150000 on expiration day or later.
# Cannot trade option SPX   240315C05150000 on expiration day or later.
# Cannot trade option SPX   240315C05150000 on expiration day or later.
# Cannot trade option SPX   240315C05150000 on expiration day or later.
# Cannot trade option SPX   240315C05150000 on expiration day or later.
# Cannot trade option SPX   240315C05150000 on expiration day or later.
# Cannot trade option SPX   240315C05150000 on expiration day or later.
# Cannot trade option SPX   240315C05150000 on expiration day or later.
# Cannot trade option SPX   240315C05135000 on expiration day or later.
# Cannot trade option SPX   240315C05135000 on expiration day or later.
# Cannot trade option SPX   240315C05135000 on expiration day or later.
# Cannot trade option SPX   240315C05135000 on expiration day or later.
# Cannot trade option SPX   240315C05135000 on expiration day or later.
# Cannot trade option SPX   240315C05135000 on expiration day or later.
# Cannot trade option SPX   240315C05135000 on expiration day or later.
# Cannot trade option SPX   240315C05135000 on expiration day or later.
# Cannot trade option SPX   240315C05135000 on expiration day or later.
# Cannot trade option SPX   240315C05150000 on expiration day or later.
# Cannot trade option SPX   240315C05150000 on expiration day or later.
# Cannot trade option SPX   240315C05150000 on expiration day or later.
# Cannot trade option SPX   240315C05150000 on expiration day or later.
# Cannot trade option SPX   240315C05150000 on expiration day or later.
# Cannot trade option SPX   240315C05150000 on expiration day or later.
# Cannot trade option SPX   240315C05150000 on expiration day or later.
# Cannot trade option SPX   240315C05150000 on expiration day or later.
# Cannot trade option SPX   240315C05150000 on expiration day or later.
# Cannot trade option SPX   240315C05130000 on expiration day or later.
# Cannot trade option SPX   240315C05130000 on expiration day or later.
# Cannot trade option SPX   240315C05130000 on expiration day or later.
# Cannot trade option SPX   240315C05130000 on expiration day or later.
# Cannot trade option SPX   240315C05130000 on expiration day or later.
# Cannot trade option SPX   240315C05130000 on expiration day or later.
# Cannot trade option SPX   240315C05130000 on expiration day or later.
# Cannot trade option SPX   240315C05130000 on expiration day or later.
# Cannot trade option SPX   240315C05130000 on expiration day or later.
#                datetime          option_symbol action  order_size
# 0   2024-01-16 16:24:28  SPX   240119C04780000      B           1
# 1   2024-01-16 16:46:54  SPX   240119P04780000      B           1
# 2   2024-01-16 16:24:28  SPX   240119C04780000      B           1
# 3   2024-01-16 16:16:42  SPX   240119P04780000      B           1
# 4   2024-01-16 16:24:28  SPX   240119C04780000      B           1
# ..                  ...                    ...    ...         ...
# 93  2024-03-13 13:59:19  SPX   240315P05170000      B           1
# 94  2024-03-13 13:48:12  SPX   240315C05175000      B           1
# 95  2024-03-13 13:40:52  SPX   240315P05170000      B           1
# 96  2024-03-13 16:26:44  SPX   240315C05170000      B           1
# 97  2024-03-13 16:31:52  SPX   240315P05170000      B           1
#
# [98 rows x 4 columns]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[1], line 8
#       6 end = datetime(2024, 3, 30)
#       7 s = Strategy()
# ----> 8 b = Backtester(start, end, s)
#
# File ~\dev\CTC-2024-Derivatives\backtester.py:20, in Backtester.__init__(self, start_date, end_date, strategy)
#      18 self.orders : pd.DataFrame = self.user_strategy.generate_orders()
#      19 self.orders["day"] = self.orders["datetime"].apply(lambda x: x.split("T")[0])
# ---> 20 self.orders["hour"] = self.orders["datetime"].apply(lambda x: int(x.split("T")[1].split(".")[0].split(":")[0]))
#      21 self.orders["minute"] = self.orders["datetime"].apply(lambda x: int(x.split("T")[1].split(".")[0].split(":")[1]))
#      22 self.orders["expiration_date"] = self.orders["option_symbol"].apply(lambda x: self.get_expiration_date(x))
#
# File ~\miniconda3\lib\site-packages\pandas\core\series.py:4771, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4661 def apply(
#    4662     self,
#    4663     func: AggFuncType,
#    (...)
#    4666     **kwargs,
#    4667 ) -> DataFrame | Series:
#    4668     """
#    4669     Invoke function on values of Series.
#    4670
#    (...)
#    4769     dtype: float64
#    4770     """
# -> 4771     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File ~\miniconda3\lib\site-packages\pandas\core\apply.py:1105, in SeriesApply.apply(self)
#    1102     return self.apply_str()
#    1104 # self.f is Callable
# -> 1105 return self.apply_standard()
#
# File ~\miniconda3\lib\site-packages\pandas\core\apply.py:1156, in SeriesApply.apply_standard(self)
#    1154     else:
#    1155         values = obj.astype(object)._values
# -> 1156         mapped = lib.map_infer(
#    1157             values,
#    1158             f,
#    1159             convert=self.convert_dtype,
#    1160         )
#    1162 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1163     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1164     #  See also GH#25959 regarding EA support
#    1165     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~\miniconda3\lib\site-packages\pandas\_libs\lib.pyx:2918, in pandas._libs.lib.map_infer()
#
# File ~\dev\CTC-2024-Derivatives\backtester.py:20, in Backtester.__init__.<locals>.<lambda>(x)
#      18 self.orders : pd.DataFrame = self.user_strategy.generate_orders()
#      19 self.orders["day"] = self.orders["datetime"].apply(lambda x: x.split("T")[0])
# ---> 20 self.orders["hour"] = self.orders["datetime"].apply(lambda x: int(x.split("T")[1].split(".")[0].split(":")[0]))
#      21 self.orders["minute"] = self.orders["datetime"].apply(lambda x: int(x.split("T")[1].split(".")[0].split(":")[1]))
#      22 self.orders["expiration_date"] = self.orders["option_symbol"].apply(lambda x: self.get_expiration_date(x))
#
# IndexError: list index out of range

# %%
b.calculate_pnl()

# %%
b.plot_pnl()

# %%
b.compute_overall_score()
